# %%
import argparse
import os
import uuid
from sqlalchemy.orm import Session

# --- Core Application Imports ---
from rfiprocessor.utils.logger import get_logger
from rfiprocessor.services.run_inference import run_inference_for_rfi

# --- Database Imports ---
from rfiprocessor.db.database import init_db, get_db_session
from rfiprocessor.db.db_models import RfiDocument, RfiStatus

# --- Initial Setup ---
logger = get_logger(__name__)

def main():
    """
    Main function to run the inference pipeline test.
    """

    input_file_path = "/Users/nagurshareefshaik/Desktop/Cogstate-RFI/data/blank/incoming/Roche on-market cognitive screener solution_2024-12-12 Blank.docx"
    if not os.path.exists(input_file_path):
        logger.error(f"Input file not found: {input_file_path}")
        return

    logger.info("--- Starting Inference Pipeline Test ---")
    
    # 1. Initialize the database
    init_db()
    
    # 2. Simulate the API's pre-computation step: Create the RFI Document record
    db_session_gen = get_db_session()
    db: Session = next(db_session_gen)
    
    new_rfi_doc = None
    try:
        logger.info("Simulating API: Creating initial RfiDocument record in the database...")
        
        # We create the record first to get a valid ID, just like the real API
        new_rfi_doc = RfiDocument(
            id=str(uuid.uuid4()), # Generate ID upfront
            title=os.path.splitext(os.path.basename(input_file_path))[0],
            source_filename=os.path.basename(input_file_path),
            status=RfiStatus.IN_PROGRESS,
            updated_by_user="test_runner"
        )
        db.add(new_rfi_doc)
        db.commit()
        db.refresh(new_rfi_doc)
        
        logger.info(f"Record created with ID: {new_rfi_doc.id}")
        
    finally:
        db.close()

    # 3. Call the core inference pipeline function
    # This function will handle its own database sessions internally.
    if new_rfi_doc:
        logger.info(f"Calling the core inference pipeline for RFI ID: {new_rfi_doc.id}")
        run_inference_for_rfi(
            rfi_doc_id=new_rfi_doc.id,
            temp_file_path=input_file_path,
            user="test_runner"
        )
        logger.info("--- Inference Pipeline Test Function Call Completed ---")
    else:
        logger.error("Failed to create the initial RFI document record. Aborting.")
        return

    # 4. (Optional) Verify the final state in the database
    db_session_gen = get_db_session()
    db: Session = next(db_session_gen)
    try:
        final_doc = db.query(RfiDocument).filter(RfiDocument.id == new_rfi_doc.id).first()
        if final_doc:
            logger.info(f"Final status for RFI ID {final_doc.id}: {final_doc.status.value}")
            logger.info(f"Final progress: {final_doc.progress}%")
            # You can uncomment the line below to see the full final payload
            # import json; print(json.dumps(final_doc.payload, indent=2))
        else:
            logger.error("Could not retrieve final document state from DB.")
    finally:
        db.close()


if __name__ == "__main__":
    main()
# Out:
# 2025-07-28 12:42:42,293 - __main__ - INFO - --- Starting Inference Pipeline Test ---
# 2025-07-28 12:42:42,294 - rfiprocessor.db.database - INFO - Initializing database and creating tables if they don't exist...
# 2025-07-28 12:42:42,296 - rfiprocessor.db.database - INFO - Database initialization complete.
# 2025-07-28 12:42:42,296 - __main__ - INFO - Simulating API: Creating initial RfiDocument record in the database...
# 2025-07-28 12:42:42,302 - __main__ - INFO - Record created with ID: 6407ec8e-12be-4f74-8054-350e25117ce0
# 2025-07-28 12:42:42,303 - __main__ - INFO - Calling the core inference pipeline for RFI ID: 6407ec8e-12be-4f74-8054-350e25117ce0
# 2025-07-28 12:42:42,303 - __main__ - INFO - Inference pipeline started for RFI ID: 6407ec8e-12be-4f74-8054-350e25117ce0
# 2025-07-28 12:42:42,321 - rfiprocessor.services.llm_provider - INFO - Initialized Advanced LLM Provider: gpt-4o
# 2025-07-28 12:42:42,321 - rfiprocessor.services.prompt_loader - INFO - Loading prompt 'rfi_parser_summary' from: rfiprocessor/prompts/rfi_parser_summary.txt
# 2025-07-28 12:42:42,322 - rfiprocessor.core.agents.blank_rfi_parser - INFO - BlankRfiParserAgent initialized successfully.
# 2025-07-28 12:42:42,324 - rfiprocessor.services.vector_store_service - INFO - Loading OpenAI embedding model: text-embedding-3-large
# 2025-07-28 12:42:42,336 - rfiprocessor.services.vector_store_service - INFO - ChromaDB service initialized. Collection 'chunks' at data/vector_store/chroma_db
# 2025-07-28 12:42:42,336 - rfiprocessor.services.llm_provider - INFO - Initialized Advanced LLM Provider: gpt-4o
# 2025-07-28 12:42:42,337 - rfiprocessor.services.prompt_loader - INFO - Loading prompt 'answer_generator' from: rfiprocessor/prompts/answer_generator.txt
# 2025-07-28 12:42:42,338 - rfiprocessor.core.agents.answer_generator - INFO - AnswerGeneratorAgent initialized successfully.
# 2025-07-28 12:42:42,338 - rfiprocessor.services.markdown_converter - INFO - Converting file: /Users/nagurshareefshaik/Desktop/Cogstate-RFI/data/blank/incoming/Roche on-market cognitive screener solution_2024-12-12 Blank.docx with markitdown
# 2025-07-28 12:42:42,356 - rfiprocessor.services.markdown_converter - INFO - Saved markdown to: data/markdown/incoming/Roche on-market cognitive screener solution_2024-12-12 Blank.md
# 2025-07-28 12:42:42,356 - rfiprocessor.core.agents.blank_rfi_parser - INFO - Generating executive summary...
# 2025-07-28 12:42:50,294 - rfiprocessor.core.agents.blank_rfi_parser - INFO - Splitting document into processable chunks...
# 2025-07-28 12:42:50,295 - rfiprocessor.core.agents.blank_rfi_parser - INFO - Processing 1 chunks concurrently...
# 2025-07-28 12:42:50,296 - rfiprocessor.core.agents.blank_rfi_parser - INFO -
# --- CHUNK SENT TO LLM ---
# **Request for Information**
#
# 1. Name of the product
#    1. Tasks to do for the patient / clinician
#    2. Cognitive Domains the tasks measure
#    3. Platform e.g. smartphone / tablet / web in what combination
#    4. Provisioned/BYOD setupTime for testing (in mins)
# 2. Intended use of the product
#    1. Device classification and FDA # (if relevant)
#    2. Clinical use environment - unsupervised remote vs supervised in-clinic
#    3. Total patients tested since the product launch
#    4. Task completion rates (% in both unsupervised and supervised/oversight environments)
#    5. Participant demographics
#       1. Age ranges
#       2. Symptomatic vs asymptomatic
#       3. Disease severity
#       4. Gold standard diagnosis
#       5. Urban vs Rural (Education levels & socioeconomic status)
# 3. Clinical validity of the product
#    1. Clinical association evidence
#    2. Usability scores from real-world participants (if any)
#    3. Test-retest reliability of screening scores
#    4. Correlation with standard screeni...
# --- END OF CHUNK ---
#
# 2025-07-28 12:42:58,179 - rfiprocessor.core.agents.blank_rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': 'Request for Information', 'description': '', 'questions': [{'question': 'Name of the product', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Tasks to do for the patient / clinician', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Cognitive Domains the tasks measure', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Platform e.g. smartphone / tablet / web in what combination', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Provisioned/BYOD setupTime for testing (in mins)', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Intended use of the product', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Device classification and FDA # (if relevant)', 'domain': 'Compliance', 'type': 'open-ended'}, {'question': 'Clinical use environment - unsupervised remote vs supervised in-clinic', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Total patients tested since the product launch', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Task completion rates (% in both unsupervised and supervised/oversight environments)', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Participant demographics', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Age ranges', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Symptomatic vs asymptomatic', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Disease severity', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Gold standard diagnosis', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Urban vs Rural (Education levels & socioeconomic status)', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Clinical validity of the product', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Clinical association evidence', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Usability scores from real-world participants (if any)', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Test-retest reliability of screening scores', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Correlation with standard screening assessments, i.e., MMSE, MoCA, PACC', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Correlation with biomarkers, i.e., MRI, PET, pTau181, pTau217', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Classification performance, i.e., sensitivity, specificity, NPV, PPV', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Availability of age and education adjusted normative data', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Product reliability', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Net promoter scores (NPS) from clinicians and patients', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Uptime and MTTR (mean time to repair)', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Any corrective action and preventive actions (CAPA) that were raised and closed?', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Market growth (at least 3 years data)', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Customer growth i.e. number of sites / customer or number of users / customer', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Revenue growth - share if possible absolute $ and % growth yoy (year over year)', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Customer profile - any reference sites of IHN (Integrated health networks)?', 'domain': 'General', 'type': 'open-ended'}], 'meta_data': {'company_name': 'Unknown', 'date': 'Unknown', 'category': 'RFI', 'type': 'PastResponse'}}
# --- END OF LLM RESPONSE ---
#
# 2025-07-28 12:42:58,180 - rfiprocessor.core.agents.blank_rfi_parser - INFO - Successfully parsed document. Found 32 questions.
# 2025-07-28 12:42:58,183 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user', 'number_of_questions']
# 2025-07-28 12:42:58,185 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Initial payload created with 32 questions.
# 2025-07-28 12:42:58,186 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 1/32: 'Name of the product...'
# 2025-07-28 12:42:58,186 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Name of the product...'
# 2025-07-28 12:42:58,749 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:42:58,749 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Name of the product...'
# 2025-07-28 12:43:00,832 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:00,837 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 2/32: 'Tasks to do for the patient / clinician...'
# 2025-07-28 12:43:00,838 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Tasks to do for the patient / clinician...'
# 2025-07-28 12:43:01,132 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:01,133 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Tasks to do for the patient / clinician...'
# 2025-07-28 12:43:06,776 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:06,781 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 3/32: 'Cognitive Domains the tasks measure...'
# 2025-07-28 12:43:06,782 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Cognitive Domains the tasks measure...'
# 2025-07-28 12:43:07,190 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:07,191 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Cognitive Domains the tasks measure...'
# 2025-07-28 12:43:10,458 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:10,463 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 4/32: 'Platform e.g. smartphone / tablet / web in what combination...'
# 2025-07-28 12:43:10,464 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Platform e.g. smartphone / tablet / web in what co...'
# 2025-07-28 12:43:10,867 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:10,868 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Platform e.g. smartphone / tablet / web in what co...'
# 2025-07-28 12:43:14,244 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:14,250 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 5/32: 'Provisioned/BYOD setupTime for testing (in mins)...'
# 2025-07-28 12:43:14,251 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Provisioned/BYOD setupTime for testing (in mins)...'
# 2025-07-28 12:43:14,557 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:14,558 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Provisioned/BYOD setupTime for testing (in mins)...'
# 2025-07-28 12:43:17,115 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:17,121 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 6/32: 'Intended use of the product...'
# 2025-07-28 12:43:17,122 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Intended use of the product...'
# 2025-07-28 12:43:17,421 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:17,422 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Intended use of the product...'
# 2025-07-28 12:43:21,361 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:21,366 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 7/32: 'Device classification and FDA # (if relevant)...'
# 2025-07-28 12:43:21,367 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Device classification and FDA # (if relevant)...'
# 2025-07-28 12:43:21,723 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:21,724 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Device classification and FDA # (if relevant)...'
# 2025-07-28 12:43:23,459 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:23,464 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 8/32: 'Clinical use environment - unsupervised remote vs supervised in-clinic...'
# 2025-07-28 12:43:23,465 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Clinical use environment - unsupervised remote vs ...'
# 2025-07-28 12:43:23,771 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:23,772 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Clinical use environment - unsupervised remote vs ...'
# 2025-07-28 12:43:27,149 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:27,155 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 9/32: 'Total patients tested since the product launch...'
# 2025-07-28 12:43:27,156 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Total patients tested since the product launch...'
# 2025-07-28 12:43:27,358 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:27,359 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Total patients tested since the product launch...'
# 2025-07-28 12:43:29,812 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:29,818 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 10/32: 'Task completion rates (% in both unsupervised and supervised/oversight...'
# 2025-07-28 12:43:29,819 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Task completion rates (% in both unsupervised and ...'
# 2025-07-28 12:43:30,018 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:30,020 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Task completion rates (% in both unsupervised and ...'
# 2025-07-28 12:43:31,965 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:31,970 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 11/32: 'Participant demographics...'
# 2025-07-28 12:43:31,971 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Participant demographics...'
# 2025-07-28 12:43:32,270 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:32,271 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Participant demographics...'
# 2025-07-28 12:43:34,734 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:34,740 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 12/32: 'Age ranges...'
# 2025-07-28 12:43:34,741 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Age ranges...'
# 2025-07-28 12:43:35,037 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:35,038 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Age ranges...'
# 2025-07-28 12:43:36,968 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:36,974 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 13/32: 'Symptomatic vs asymptomatic...'
# 2025-07-28 12:43:36,975 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Symptomatic vs asymptomatic...'
# 2025-07-28 12:43:37,175 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:37,177 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Symptomatic vs asymptomatic...'
# 2025-07-28 12:43:40,664 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:40,668 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 14/32: 'Disease severity...'
# 2025-07-28 12:43:40,668 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Disease severity...'
# 2025-07-28 12:43:41,075 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:41,076 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Disease severity...'
# 2025-07-28 12:43:42,813 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:42,817 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 15/32: 'Gold standard diagnosis...'
# 2025-07-28 12:43:42,818 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Gold standard diagnosis...'
# 2025-07-28 12:43:43,437 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:43,458 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Gold standard diagnosis...'
# 2025-07-28 12:43:45,046 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:45,053 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 16/32: 'Urban vs Rural (Education levels & socioeconomic status)...'
# 2025-07-28 12:43:45,054 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Urban vs Rural (Education levels & socioeconomic s...'
# 2025-07-28 12:43:45,294 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:45,295 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Urban vs Rural (Education levels & socioeconomic s...'
# 2025-07-28 12:43:47,723 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:47,728 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 17/32: 'Clinical validity of the product...'
# 2025-07-28 12:43:47,729 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Clinical validity of the product...'
# 2025-07-28 12:43:47,936 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:47,937 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Clinical validity of the product...'
# 2025-07-28 12:43:53,565 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:53,568 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 18/32: 'Clinical association evidence...'
# 2025-07-28 12:43:53,568 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Clinical association evidence...'
# 2025-07-28 12:43:53,746 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:53,747 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Clinical association evidence...'
# 2025-07-28 12:43:56,402 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:56,406 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 19/32: 'Usability scores from real-world participants (if any)...'
# 2025-07-28 12:43:56,407 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Usability scores from real-world participants (if ...'
# 2025-07-28 12:43:56,612 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:56,613 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Usability scores from real-world participants (if ...'
# 2025-07-28 12:43:57,968 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:57,971 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 20/32: 'Test-retest reliability of screening scores...'
# 2025-07-28 12:43:57,972 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Test-retest reliability of screening scores...'
# 2025-07-28 12:43:58,171 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:43:58,172 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Test-retest reliability of screening scores...'
# 2025-07-28 12:43:59,710 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:43:59,716 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 21/32: 'Correlation with standard screening assessments, i.e., MMSE, MoCA, PAC...'
# 2025-07-28 12:43:59,716 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Correlation with standard screening assessments, i...'
# 2025-07-28 12:44:00,121 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:44:00,123 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Correlation with standard screening assessments, i...'
# 2025-07-28 12:44:02,373 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:44:02,379 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 22/32: 'Correlation with biomarkers, i.e., MRI, PET, pTau181, pTau217...'
# 2025-07-28 12:44:02,380 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Correlation with biomarkers, i.e., MRI, PET, pTau1...'
# 2025-07-28 12:44:03,093 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:44:03,094 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Correlation with biomarkers, i.e., MRI, PET, pTau1...'
# 2025-07-28 12:44:06,165 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:44:06,171 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 23/32: 'Classification performance, i.e., sensitivity, specificity, NPV, PPV...'
# 2025-07-28 12:44:06,171 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Classification performance, i.e., sensitivity, spe...'
# 2025-07-28 12:44:06,406 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:44:06,407 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Classification performance, i.e., sensitivity, spe...'
# 2025-07-28 12:44:08,015 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:44:08,021 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 24/32: 'Availability of age and education adjusted normative data...'
# 2025-07-28 12:44:08,021 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Availability of age and education adjusted normati...'
# 2025-07-28 12:44:08,319 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:44:08,321 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Availability of age and education adjusted normati...'
# 2025-07-28 12:44:11,078 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:44:11,084 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 25/32: 'Product reliability...'
# 2025-07-28 12:44:11,085 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Product reliability...'
# 2025-07-28 12:44:11,300 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:44:11,301 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Product reliability...'
# 2025-07-28 12:44:14,866 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:44:14,872 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 26/32: 'Net promoter scores (NPS) from clinicians and patients...'
# 2025-07-28 12:44:14,872 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Net promoter scores (NPS) from clinicians and pati...'
# 2025-07-28 12:44:15,280 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:44:15,281 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Net promoter scores (NPS) from clinicians and pati...'
# 2025-07-28 12:44:16,609 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:44:16,615 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 27/32: 'Uptime and MTTR (mean time to repair)...'
# 2025-07-28 12:44:16,616 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Uptime and MTTR (mean time to repair)...'
# 2025-07-28 12:44:16,948 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:44:16,949 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Uptime and MTTR (mean time to repair)...'
# 2025-07-28 12:44:18,582 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:44:18,588 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 28/32: 'Any corrective action and preventive actions (CAPA) that were raised a...'
# 2025-07-28 12:44:18,589 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Any corrective action and preventive actions (CAPA...'
# 2025-07-28 12:44:18,802 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:44:18,803 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Any corrective action and preventive actions (CAPA...'
# 2025-07-28 12:44:20,809 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:44:20,814 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 29/32: 'Market growth (at least 3 years data)...'
# 2025-07-28 12:44:20,815 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Market growth (at least 3 years data)...'
# 2025-07-28 12:44:21,004 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:44:21,005 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Market growth (at least 3 years data)...'
# 2025-07-28 12:44:23,441 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:44:23,449 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 30/32: 'Customer growth i.e. number of sites / customer or number of users / c...'
# 2025-07-28 12:44:23,449 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Customer growth i.e. number of sites / customer or...'
# 2025-07-28 12:44:23,776 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:44:23,777 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Customer growth i.e. number of sites / customer or...'
# 2025-07-28 12:44:25,514 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:44:25,518 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 31/32: 'Revenue growth - share if possible absolute $ and % growth yoy (year o...'
# 2025-07-28 12:44:25,519 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Revenue growth - share if possible absolute $ and ...'
# 2025-07-28 12:44:25,825 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:44:25,826 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Revenue growth - share if possible absolute $ and ...'
# 2025-07-28 12:44:28,897 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:44:28,905 - __main__ - INFO - [6407ec8e-12be-4f74-8054-350e25117ce0] Processing question 32/32: 'Customer profile - any reference sites of IHN (Integrated health netwo...'
# 2025-07-28 12:44:28,906 - rfiprocessor.services.vector_store_service - INFO - Performing similarity search for query: 'Customer profile - any reference sites of IHN (Int...'
# 2025-07-28 12:44:29,109 - rfiprocessor.services.vector_store_service - INFO - Found 5 relevant chunks for the query.
# 2025-07-28 12:44:29,110 - rfiprocessor.core.agents.answer_generator - INFO - Generating answer for question: 'Customer profile - any reference sites of IHN (Int...'
# 2025-07-28 12:44:30,533 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['payload', 'progress', 'updated_by_user']
# 2025-07-28 12:44:30,540 - rfiprocessor.services.db_handler - INFO - Updating record ID 6407ec8e-12be-4f74-8054-350e25117ce0 in rfi_documents with: ['status', 'progress']
# 2025-07-28 12:44:30,544 - __main__ - INFO - Successfully processed RFI ID: 6407ec8e-12be-4f74-8054-350e25117ce0. Status set to REVIEW_READY.
# 2025-07-28 12:44:30,546 - __main__ - INFO - Cleaned up temporary file: /Users/nagurshareefshaik/Desktop/Cogstate-RFI/data/blank/incoming/Roche on-market cognitive screener solution_2024-12-12 Blank.docx
# 2025-07-28 12:44:30,546 - __main__ - INFO - --- Inference Pipeline Test Function Call Completed ---
# 2025-07-28 12:44:30,547 - __main__ - INFO - Final status for RFI ID 6407ec8e-12be-4f74-8054-350e25117ce0: REVIEW_READY
# 2025-07-28 12:44:30,548 - __main__ - INFO - Final progress: 100%
